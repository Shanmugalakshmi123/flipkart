# %%
import time
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By


driver = webdriver.Chrome()  # Optional argument, if not specified will search path.

driver.get('https://www.bbc.com/news/uk-67584565')
viewall=driver.get(By.XPATH,"//span[text()='VIEW ALL']")
for i in range(0,len(viewall)):
    viewall[i].click()
    individual=driver.get(By.XPATH,"//img[@]")
    for j in range(0,len(individual)):
        individual[j].click()
        time.sleep(10)

# %%
import time
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import json
#from webdriver_manager.chrome import ChromeDriverManager

driver=webdriver.Chrome()
#driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=b4a00308-6d1e-4243-897f-d0829e1d1db9&as-backfill=on")

for j in range(1,3,1):
    links1=driver.find_elements(By.XPATH,"//a[@class='_1fQZEK']")
    links=[]
    for link in links1:
        links.append(link.get_attribute('href'))

    for link in links: 
        driver.execute_script("window.open();") # open a new tab
        driver.switch_to.window(driver.window_handles[1])   # switch to the tab 1
        driver.get(link)

        driver.close() # close tab 1
        driver.switch_to.window(driver.window_handles[0])
    description=driver.find_elements(By.XPATH,"//div[@class='_4rR01T']")
    # for i in description:
    #     print(i.text)
    configuration=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']")
    for i in configuration:
        config=i.find_elements(By.TAG_NAME,"li")
        #for j in range(len(config)):
        processor=config[0].text
        ram=config[1].text
        os1=config[2].text
        harddisk=config[3].text
        display=config[4].text
        try:
            warranty=config[5].text
            #print(processor,ram,harddisk,os1,display,warranty)
        except:
            pass
    # with open('sites.json', encoding='utf-8') as s:
    #     data = json.loads(s.read())
    laptops=driver.find_elements(By.XPATH,"//img[@loading='eager']")
    for i in laptops:
        x=i.get_attribute("src")
        #print(x)


    #print(description)
    # laptops=driver.find_elements(By.XPATH,"//img[@loading='eager']")
    # print(len(laptops))
    # for i in range(0,len(laptops)):
    #     laptops[i].click()
    #     #time.sleep(5)
    #     #driver.back()
    driver.find_element(By.XPATH,"//span[contains(text(),'Next')]").click()
    time.sleep(3)
     # close tab 1

# %%
import time
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import json
#from webdriver_manager.chrome import ChromeDriverManager

driver=webdriver.Chrome()
#driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=b4a00308-6d1e-4243-897f-d0829e1d1db9&as-backfill=on")

links1=driver.find_elements(By.XPATH,"//a[@class='_1fQZEK']")
links=[]
for link in links1:
    links.append(link.get_attribute('href'))

for link in links: 
    driver.execute_script("window.open();") # open a new tab
    driver.switch_to.window(driver.window_handles[1])   # switch to the tab 1
    driver.get(link)
    driver.close() # close tab 1
    driver.switch_to.window(driver.window_handles[0])
# for link in links: 
#     driver.execute_script("window.open();") # open a new tab
#     driver.switch_to.window(driver.window_handles[1])   # switch to the tab 1
#     driver.get(link)
#     driver.close()

# %%
import time
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import json
import pandas as pd
from bs4 import BeautifulSoup
import requests
#from webdriver_manager.chrome import ChromeDriverManager

driver=webdriver.Chrome()
#driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=b4a00308-6d1e-4243-897f-d0829e1d1db9&as-backfill=on")

for j in range(1,2,1):
    links1=driver.find_elements(By.XPATH,"//a[@class='_1fQZEK']")
    links=[]
    for link in links1:
        links.append(link.get_attribute('href'))
    
    for link in links: 
        driver.execute_script("window.open();") # open a new tab
        driver.switch_to.window(driver.window_handles[1])   # switch to the tab 1
        driver.get(link)
        description=driver.find_elements(By.XPATH,"//span[@class='B_NuCI']")
        desc=[]
        for i in description:
            #print(i.text)
            desc.append(i.text)
        target=driver.find_elements(By.XPATH,"//table[@class='_14cfVK']")
        py_data = requests.get(link).text
        py_soup = BeautifulSoup (py_data, 'html.parser')
        py_table= py_soup.find ('table', attrs = {'class':'_14cfVK'})
        py_rows = py_table.find_all ('tr')
        for row in py_rows:
            cols = row.find_all ('td')
            cols = [ele.text.strip() for ele in cols]
            cols = [ele for ele in cols if ele] # Get rid of empty values
            #print (cols)
        ratings=driver.find_elements(By.XPATH,"//div[@class='_3LWZlK']")
        ratings1=[]
        for i in ratings:
            #print(i.text)
            ratings1.append(i.text)
        
        #print ('Classes of each table:')
        #for table in py_soup.find_all ('table'):
        #    print (table.text)
        driver.close() # close tab 1
        driver.switch_to.window(driver.window_handles[0])
    
        
    driver.find_element(By.XPATH,"//span[contains(text(),'Next')]").click()
    time.sleep(3)
     # close tab 1
# Out:
# 4.3
# 4.3
# 4.2
# 4
# 4.2
# 4.2
# 3.7
# 4.5
# 4.7
# 4.7
# 4.3
# 4.6
# 4.7
# 4.7
# 4.3
# 4.6
# 4.3
# 4.3
# 4
# 4
# 4.5
# 4.5
# 4
# 4.1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 32
#      30 py_soup = BeautifulSoup (py_data, 'html.parser')
#      31 py_table= py_soup.find ('table', attrs = {'class':'_14cfVK'})
# ---> 32 py_rows = py_table.find_all ('tr')
#      33 for row in py_rows:
#      34     cols = row.find_all ('td')
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
pip install tabScript
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement tabScript (from versions: none)
# ERROR: No matching distribution found for tabScript
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: c:\new\first\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
pip install webdriver_manager
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: c:\new\first\.venv\Scripts\python.exe -m pip install --upgrade pip
#   Obtaining dependency information for webdriver_manager from https://files.pythonhosted.org/packages/b1/51/b5c11cf739ac4eecde611794a0ec9df420d0239d51e73bc19eb44f02b48b/webdriver_manager-4.0.1-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for requests from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/b6/7c/8debebb4f90174074b827c63242c23851bdf00a532489fba57fef3416e40/charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata
#   Using cached charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# ...

# %%
pip install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/ae/d9/3741b344f57484b423cd22194025a8489992ad9962196a62721ef9980045/pandas-2.1.4-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for numpy<2,>=1.26.0 from https://files.pythonhosted.org/packages/ad/11/52fbe97fd84c91105b651d25a122f8deed6d3519afb14f9771fac1c9b7de/numpy-1.26.3-cp312-cp312-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.2 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.2 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 61.2/61.2 kB 653.5 kB/s eta 0:00:00
# ...

# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: c:\new\first\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
pip install bs4
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
# ...
#   Obtaining dependency information for soupsieve>1.2 from https://files.pythonhosted.org/packages/4c/f3/038b302fdfbe3be7da016777069f26ceefe11a681055ea1f7817546508e3/soupsieve-2.5-py3-none-any.whl.metadata
#   Using cached soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1262 sha256=cd4a6507deeeb1fbfb0a02518115b7b38b2f206aacb2ba9d4018418826d6e4ff
# ...
