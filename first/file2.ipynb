# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.remote.webelement import WebElement
driver = webdriver.Chrome()  # Optional argument, if not specified will search path.

driver.maximize_window()

driver.get('https://www.flipkart.com/gaming-laptops-store?otracker=nmenu_sub_Electronics_0_Gaming%20Laptops&otracker=nmenu_sub_Electronics_0_Gaming%20Laptops')

time.sleep(3)
details = {'Description':[],'Discountprice':[],
           'Actualprice':[],'Discountpercent':[],'Links':[],'ImageLinks':[]}
ElementBoxes = driver.find_elements(By.CSS_SELECTOR,"div._1xC019")
#driver.find_element(By.XPATH,"//span[contains(text(),'VIEW ALL')]").click()
#driver.find_element(By.XPATH,"//a[class='_2KpZ61 _3dESVI']").click()
#driver.find_element(By.CSS_SELECTOR("div._1xC019").get_attribute('class')).click(
#driver.find_elements(By.CSS_SELECTOR,"a[class='_2KpZ61 _3dESVI']").click()    
#link=driver.find_elements(By.XPATH,"//a[class='_2KpZ61 _3dESVI']/span[contains(text(),'VIEW ALL')]").__getattribute__
# for i in ElementBoxes:
#     print(i)
#     link = i.find_element(By.CSS_SELECTOR,'a._2KpZ61 _3dESVI').get_attribute('href')
# #     print(link)
# for i in range(5):

#     ElementBoxes = driver.find_elements(By.CSS_SELECTOR,"div._1xC019")
#     for j in ElementBoxes:
#driver.find_element(By.CLASS_NAME,'_2KpZ61 _3dESVI').click()
        #link = j.find_element(By.CSS_SELECTOR,'a._2KpZ61 _3dESVI').get_attribute('href'
viewall= driver.find_elements(By.XPATH,"//a[span[contains(text(),'VIEW ALL')]]") 
print(len(viewall))
for i in viewall:
    i.click()
    individual= driver.find_elements(By.XPATH,"//img[@loading='eager']")
    time.sleep(3)
    for j in range(0,len(individual)):
        if individual[j].is_displayed():
            individual[j].click()
        #time.sleep(3)
        
        #driver.switch_to.window(driver.window_handles[1])
    driver.switch_to.window(driver.window_handles[0])
# for i in viewall:
#     i.click()
#     time.sleep(3)
#     driver.switchTo().defaultContent()
    #driver.execute_script("window.history.go(-1)")
    #individual= driver.find_elements(By.XPATH,"//img[@loading='eager']")
    # for j in individual:
    #     try:j.click()
        
    #     except:pass
        #driver.execute_script("window.history.go(-1)")
        #driver.back()
        #time.sleep(3)
        #print(j)
# Out:
# 6
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[23], line 40
#      38 time.sleep(3)
#      39 for j in range(0,len(individual)):
# ---> 40     individual[j].click()
#      41     #time.sleep(3)
#      43     driver.switch_to.window(driver.window_handles[1])
#
# File c:\new\first\.venv\Lib\site-packages\selenium\webdriver\remote\webelement.py:93, in WebElement.click(self)
#      91 def click(self) -> None:
#      92     """Clicks the element."""
# ---> 93     self._execute(Command.CLICK_ELEMENT)
#
# File c:\new\first\.venv\Lib\site-packages\selenium\webdriver\remote\webelement.py:394, in WebElement._execute(self, command, params)
#     392     params = {}
#     393 params["id"] = self._id
# --> 394 return self._parent.execute(command, params)
#
# File c:\new\first\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File c:\new\first\.venv\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: stale element not found
#   (Session info: chrome=120.0.6099.217); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF620DE2142+3514994]
# 	(No symbol) [0x00007FF620A00CE2]
# 	(No symbol) [0x00007FF6208A76AA]
# 	(No symbol) [0x00007FF6208ACFC0]
# 	(No symbol) [0x00007FF6208AF38F]
# 	(No symbol) [0x00007FF6208AF480]
# 	(No symbol) [0x00007FF6208F3569]
# 	(No symbol) [0x00007FF6208E6966]
# 	(No symbol) [0x00007FF620915FEA]
# 	(No symbol) [0x00007FF6208E63B6]
# 	(No symbol) [0x00007FF620916490]
# 	(No symbol) [0x00007FF6209328F6]
# 	(No symbol) [0x00007FF620915D93]
# 	(No symbol) [0x00007FF6208E4BDC]
# 	(No symbol) [0x00007FF6208E5C64]
# 	GetHandleVerifier [0x00007FF620E0E16B+3695259]
# 	GetHandleVerifier [0x00007FF620E66737+4057191]
# 	GetHandleVerifier [0x00007FF620E5E4E3+4023827]
# 	GetHandleVerifier [0x00007FF620B304F9+689705]
# 	(No symbol) [0x00007FF620A0C048]
# 	(No symbol) [0x00007FF620A08044]
# 	(No symbol) [0x00007FF620A081C9]
# 	(No symbol) [0x00007FF6209F88C4]
# 	BaseThreadInitThunk [0x00007FFDD551257D+29]
# 	RtlUserThreadStart [0x00007FFDD64EAA58+40]

# %%
driver = webdriver.Chrome()  # Optional argument, if not specified will search path.

driver.maximize_window()

driver.get('https://www.flipkart.com/womens-footwear/sports-shoes/pr?sid=osp,iko,d20&fm=neo%2Fmerchandising&iid=M_487227f1-a5f3-48fa-a1e9-1239bc93b34c_1_372UD5BXDFYS_MC.TCYGDE7YX2GZ&otracker=hp_rich_navigation_7_1.navigationCard.RICH_NAVIGATION_Fashion~Women%2BFootwear~Women%2BSports%2BShoes_TCYGDE7YX2GZ&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_7_L2_view-all&cid=TCYGDE7YX2GZ')

time.sleep(3)

for i in range(5):

    ElementBoxes = driver.find_elements(By.CSS_SELECTOR,"div._1xHGtK")

    for i in ElementBoxes:
        
        try:image = i.find_element(By.CSS_SELECTOR,"img._2r_T1I").get_attribute('src')
        except:image = None
        
        try:brand = i.find_element(By.CSS_SELECTOR,'div._2WkVRV').text
        except:brand = None
        
        try:description = i.find_element(By.CSS_SELECTOR,"a.IRpwTa").get_attribute('title')
        except: description = None
        
        try:discountprice = i.find_element(By.CSS_SELECTOR,'div._30jeq3').text
        except:discountprice = None
        
        try:actualprice = i.find_element(By.CSS_SELECTOR,'div._3I9_wc').text
        except:actualprice = None
        
        try:discountpercent = i.find_element(By.CSS_SELECTOR,'div._3Ay6Sb').text
        except:discountpercent = None
        
        try:link = i.find_element(By.CSS_SELECTOR,'a.IRpwTa').get_attribute('href')
        except:link = None
        
        details['Links'].append(link)
        details['ImageLinks'].append(image)
        details['Brand'].append(brand)
        details['Description'].append(description)
        details['Discountprice'].append(discountprice)
        details['Actualprice'].append(actualprice)
        details['Discountpercent'].append(discountpercent)
    
    driver.find_element(By.XPATH,"//span[contains(text(),'Next')]").click()

    time.sleep(3)

# %%
for i in range(5):

    ElementBoxes = driver.find_elements(By.CSS_SELECTOR,"div._1xHGtK")

    #for i in ElementBoxes:
        
        #try:image = i.find_element(By.CSS_SELECTOR,"img._2r_T1I").get_attribute('src')
        #except:image = None
        
        #@try:brand = i.find_element(By.CSS_SELECTOR,'div._2WkVRV').text
        #@except:brand = None
        
        #try:description = i.find_element(By.CSS_SELECTOR,"div._1xC019").get_attribute('class')
        #except: description = None
        
        #try:discountprice = i.find_element(By.CSS_SELECTOR,'div._30jeq3').text
        #except:discountprice = None
        
        #try:actualprice = i.find_element(By.CSS_SELECTOR,'div._3I9_wc').text
        #except:actualprice = None
        
        #try:discountpercent = i.find_element(By.CSS_SELECTOR,'div._3Ay6Sb').text
        #except:discountpercent = None
        
        #try:link = i.find_element(By.CSS_SELECTOR,'a.IRpwTa').get_attribute('href')
        #except:link = None
        
        #details['Links'].append(link)
        #details['ImageLinks'].append(image)
        #details['Brand'].append(brand)
        #details['Description'].append(description)
        #details['Discountprice'].append(discountprice)
        #details['Actualprice'].append(actualprice)
        #details['Discountpercent'].append(discountpercent)
    
    driver.find_element(By.XPATH,"//span[contains(text(),'VIEW ALL')]").click()

    time.sleep(3)

# %%
for i in details.keys():
    
    print(i,len(details[i]))
